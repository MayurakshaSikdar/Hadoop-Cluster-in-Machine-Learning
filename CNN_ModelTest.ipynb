# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import os
import cv2
import glob
from scipy.misc.pilutil import Image #Convert Image to grayscale
import matplotlib.pyplot as plt # For creating plot
import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# Using TensorFlow backend.

# %%
img_width, img_height, resize_dim = 32,32,32

# %%
model = load_model('model_filter_v2.h5')
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# path = os.path.join('Demo Test','7.png')

# img=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
# img=cv2.resize(img,(resize_dim,resize_dim),interpolation=cv2.INTER_AREA)
# gaussian_3 = cv2.GaussianBlur(img, (9,9), 10.0)
# img = cv2.addWeighted(img, 1.5, gaussian_3, -0.5, 0, img)
# kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
# img = cv2.filter2D(img, -1, kernel)

# plt.imshow(img)

# %%
# hist = cv2.calcHist(img,[0],None,[256],[0,256])
# plt.hist(img.ravel(),256,[0,256])
# # show Histogram
# plt.show()

# %%
# img = np.expand_dims(img, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
# img = np.expand_dims(img, axis=3)

# %%
# images = np.vstack([img])
# classes = model.predict_classes(img)
# print(classes)

# %%
file = '.png'
for i in range(10):
    path = os.path.join('Demo Test', str(i)+file)
    
    imgOriginal = cv2.imread(path)
    img=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
    
    img=cv2.resize(img,(resize_dim,resize_dim),interpolation=cv2.INTER_AREA)
    gaussian_3 = cv2.GaussianBlur(img, (9,9), 10.0)
    img = cv2.addWeighted(img, 1.5, gaussian_3, -0.5, 0, img)
    kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    img = cv2.filter2D(img, -1, kernel)
    
    plt.subplot(221)
    plt.imshow(imgOriginal)
    plt.subplot(222)
    plt.imshow(img)
    plt.show()
    
    img = np.expand_dims(img, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img = np.expand_dims(img, axis=3)
    
    images = np.vstack([img])
    classes = model.predict_classes(img)
    print('PREDICTION --> '+str(classes[0]))
    input()
    print('---------------------------------------------------------')
# Out:
# PREDICTION --> 0
#
# ---------------------------------------------------------
# PREDICTION --> 1
#
# ---------------------------------------------------------
# PREDICTION --> 2
#
# ---------------------------------------------------------
# PREDICTION --> 3
#
# ---------------------------------------------------------
# PREDICTION --> 4
#
# ---------------------------------------------------------
# PREDICTION --> 5
#
# ---------------------------------------------------------
# PREDICTION --> 6
#
# ---------------------------------------------------------
# PREDICTION --> 7
#
# ---------------------------------------------------------
# PREDICTION --> 8
#
# ---------------------------------------------------------
# PREDICTION --> 9
#
# ---------------------------------------------------------
